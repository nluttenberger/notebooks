# %% [markdown]
# # How to learn from the Ingredient Graph
#
# This notebook explains how to create an Ingredient Graph (IG) from several json input files.
#
# ### Importing several Python modules
#
# For reading json files, we need the `json` package. For setting the correct collation for sorting node identifiers, we need the `locale` package.

# %%
import sys
# !{sys.executable} -m pip install networkx
# {sys.executable} -m pip install matplotlib
# !{sys.executable} -m pip install mlxtend
# !{sys.executable} -m pip install xlwt
# !{sys.executable} -m pip install openpyxl
# import networkx as nx
# G = nx.Graph()
import json
# import matplotlib.pyplot as plt
import locale
locale.setlocale(locale.LC_ALL, 'de-DE.utf-8')
import matplotlib.pyplot as plt
import openpyxl
import numpy as np
from mlxtend.plotting import heatmap
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}

# %% [markdown]
# Read json file for **Yotam Ottolenghi's "Flavour"** recipes and create array [recipe][ingredients].

# %%
with open('recipes_YO_Flavour.json', encoding='utf-8') as file:
    data = json.load(file)
flv_arr = []
for rcp in data:
    row = rcp["ingredients"]
    flv_arr.append(row)
#print (flv_arr)

# %% [markdown]
# Transform array to pandas data frame.

# %%
te = TransactionEncoder()
te_ary = te.fit(flv_arr).transform(flv_arr)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     ahornsirup  ancho  apfel  apfelessig  aprikose  auberginen  austernpilz  \
# 0         True  False  False        True     False       False        False
# 1         True  False  False       False     False       False        False
# 2        False  False  False       False     False       False        False
# 3        False  False  False       False     False        True        False
# 4         True  False  False       False      True       False        False
# ..         ...    ...    ...         ...       ...         ...          ...
# 87       False  False  False       False     False       False        False
# 88        True  False  False       False     False       False        False
# 89       False  False  False       False     False       False        False
# 90       False  False  False       False     False       False        False
# 91        True  False  False       False     False       False        False
#
#     avocado  babyspinat  balsamico  ...  weißweinessig  worcester  zatar  \
# 0     False       False      False  ...          False      False  False
# 1     False       False      False  ...          False      False  False
# 2     False        True      False  ...          False      False  False
# 3     False        True      False  ...          False      False  False
# 4     False       False      False  ...          False      False  False
# ..      ...         ...        ...  ...            ...        ...    ...
# 87    False       False      False  ...          False      False  False
# 88    False       False      False  ...          False      False  False
# 89    False       False      False  ...          False      False  False
# 90    False       False      False  ...          False      False  False
# 91    False       False      False  ...          False      False  False
#
#     ziegenfrischkäse   zimt  zitrone  zucchini  zucker  zuckerschoten  zwiebel
# 0              False  False     True     False   False          False    False
# 1              False  False    False     False    True          False    False
# 2              False  False    False     False   False          False    False
# 3              False   True     True     False   False          False     True
# 4              False  False    False     False   False          False    False
# ..               ...    ...      ...       ...     ...            ...      ...
# 87             False   True    False     False   False          False     True
# 88             False  False    False     False    True          False    False
# 89             False  False    False     False   False          False    False
# 90             False  False     True     False    True          False    False
# 91             False   True    False     False   False          False    False
#
# [92 rows x 222 columns]

# %% [markdown]
# Compute ingredient co-occurrences.

# %%
frequent_itemsets=apriori(df, min_support=0.2, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.to_excel('fp_flv.xlsx')
frequent_itemsets
# Out:
#      support                            itemsets  length
# 0   0.554348                       (chilischote)       1
# 1   0.239130                             (cumin)       1
# 2   0.228261                            (ingwer)       1
# 3   0.793478                         (knoblauch)       1
# 4   0.217391                     (koriandergrün)       1
# 5   0.206522                      (lauchzwiebel)       1
# 6   0.423913                           (limette)       1
# 7   0.760870                          (olivenöl)       1
# 8   0.206522                        (petersilie)       1
# 9   0.206522                             (sesam)       1
# 10  0.206522                         (sojasauce)       1
# 11  0.250000                    (sonnenblumenöl)       1
# 12  0.304348                           (zitrone)       1
# 13  0.239130                            (zucker)       1
# 14  0.271739                           (zwiebel)       1
# 15  0.445652            (chilischote, knoblauch)       2
# 16  0.271739              (chilischote, limette)       2
# 17  0.423913             (olivenöl, chilischote)       2
# 18  0.217391                   (cumin, olivenöl)       2
# 19  0.336957                (knoblauch, limette)       2
# 20  0.630435               (olivenöl, knoblauch)       2
# 21  0.206522         (sonnenblumenöl, knoblauch)       2
# 22  0.250000                (zitrone, knoblauch)       2
# 23  0.206522                 (knoblauch, zucker)       2
# 24  0.217391                (zwiebel, knoblauch)       2
# 25  0.293478                 (olivenöl, limette)       2
# 26  0.206522              (olivenöl, petersilie)       2
# 27  0.293478                 (zitrone, olivenöl)       2
# 28  0.239130                 (zwiebel, olivenöl)       2
# 29  0.217391   (knoblauch, chilischote, limette)       3
# 30  0.347826  (olivenöl, chilischote, knoblauch)       3
# 31  0.239130      (knoblauch, olivenöl, limette)       3
# 32  0.239130      (zitrone, olivenöl, knoblauch)       3
# 33  0.206522      (zwiebel, olivenöl, knoblauch)       3

# %% [markdown]
# Create association rules.

# %%
association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
# Out:
#                  antecedents               consequents  antecedent support  \
# 0              (chilischote)               (knoblauch)            0.554348
# 1                (knoblauch)             (chilischote)            0.793478
# 2              (chilischote)                 (limette)            0.554348
# 3                  (limette)             (chilischote)            0.423913
# 4                 (olivenöl)             (chilischote)            0.760870
# 5              (chilischote)                (olivenöl)            0.554348
# 6                    (cumin)                (olivenöl)            0.239130
# 7                 (olivenöl)                   (cumin)            0.760870
# 8                (knoblauch)                 (limette)            0.793478
# 9                  (limette)               (knoblauch)            0.423913
# 10                (olivenöl)               (knoblauch)            0.760870
# 11               (knoblauch)                (olivenöl)            0.793478
# 12          (sonnenblumenöl)               (knoblauch)            0.250000
# 13               (knoblauch)          (sonnenblumenöl)            0.793478
# 14                 (zitrone)               (knoblauch)            0.304348
# 15               (knoblauch)                 (zitrone)            0.793478
# 16               (knoblauch)                  (zucker)            0.793478
# 17                  (zucker)               (knoblauch)            0.239130
# 18                 (zwiebel)               (knoblauch)            0.271739
# 19               (knoblauch)                 (zwiebel)            0.793478
# 20                (olivenöl)                 (limette)            0.760870
# 21                 (limette)                (olivenöl)            0.423913
# 22                (olivenöl)              (petersilie)            0.760870
# 23              (petersilie)                (olivenöl)            0.206522
# 24                 (zitrone)                (olivenöl)            0.304348
# 25                (olivenöl)                 (zitrone)            0.760870
# 26                 (zwiebel)                (olivenöl)            0.271739
# 27                (olivenöl)                 (zwiebel)            0.760870
# 28  (chilischote, knoblauch)                 (limette)            0.445652
# 29      (limette, knoblauch)             (chilischote)            0.336957
# 20            0.423913  0.293478    0.385714  0.909890 -0.029064    0.937816
# 21            0.760870  0.293478    0.692308  0.909890 -0.029064    0.777174
# 22            0.206522  0.206522    0.271429  1.314286  0.049386    1.089088
# 23            0.760870  0.206522    1.000000  1.314286  0.049386         inf
# 24            0.760870  0.293478    0.964286  1.267347  0.061909    6.695652
# 25            0.304348  0.293478    0.385714  1.267347  0.061909    1.132457
# 26            0.760870  0.239130    0.880000  1.156571  0.032372    1.992754
# 27            0.271739  0.239130    0.314286  1.156571  0.032372    1.062047
# 28            0.423913  0.217391    0.487805  1.150719  0.028474    1.124741
# 29            0.554348  0.217391    0.645161  1.163820  0.030600    1.255929
# 30            0.793478  0.217391    0.800000  1.008219  0.001772    1.032609
# 31            0.271739  0.217391    0.273973  1.008219  0.001772    1.003076
# 32            0.336957  0.217391    0.392157  1.163820  0.030600    1.090813
# 33            0.445652  0.217391    0.512821  1.150719  0.028474    1.137872
# 34            0.793478  0.347826    0.820513  1.034071  0.011460    1.150621
# 35            0.554348  0.347826    0.551724  0.995267 -0.001654    0.994147
# 36            0.760870  0.347826    0.780488  1.025784  0.008743    1.089372
# 37            0.445652  0.347826    0.457143  1.025784  0.008743    1.021167
# 38            0.630435  0.347826    0.627451  0.995267 -0.001654    0.991991
# 39            0.423913  0.347826    0.438356  1.034071  0.011460    1.025716
# 40            0.423913  0.239130    0.379310  0.894783 -0.028119    0.928140
# 41            0.760870  0.239130    0.709677  0.932719 -0.017250    0.823671
# 42            0.793478  0.239130    0.814815  1.026890  0.006262    1.115217
# 43            0.293478  0.239130    0.301370  1.026890  0.006262    1.011296
# 44            0.336957  0.239130    0.314286  0.932719 -0.017250    0.966938
# 45            0.630435  0.239130    0.564103  0.894783 -0.028119    0.847826
# 46            0.793478  0.239130    0.814815  1.026890  0.006262    1.115217
# 47            0.760870  0.239130    0.956522  1.257143  0.048913    5.500000
# 48            0.304348  0.239130    0.379310  1.246305  0.047259    1.120773
# 49            0.630435  0.239130    0.785714  1.246305  0.047259    1.724638
# 50            0.250000  0.239130    0.314286  1.257143  0.048913    1.093750
# 51            0.293478  0.239130    0.301370  1.026890  0.006262    1.011296
# 52            0.793478  0.206522    0.863636  1.088418  0.016777    1.514493
# 53            0.760870  0.206522    0.950000  1.248571  0.041115    4.782609
# 54            0.271739  0.206522    0.327586  1.205517  0.035208    1.083055
# 55            0.630435  0.206522    0.760000  1.205517  0.035208    1.539855
# 56            0.217391  0.206522    0.271429  1.248571  0.041115    1.074169
# 57            0.239130  0.206522    0.260274  1.088418  0.016777    1.028583

# %% [markdown]
# Read json file for **Henriette Davidis Gemüse chapter** and create array [recipe][ingredients].

# %%
with open('recipes_HD_Gemüse.json', encoding='utf-8') as file:
    data = json.load(file)
hdg_arr = []
for rcp in data:
    row = rcp["ingredients"]
    hdg_arr.append(row)
#print (hdg_arr)

# %% [markdown]
# Transform array to pandas data frame.

# %%
te = TransactionEncoder()
te_ary = te.fit(hdg_arr).transform(hdg_arr)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#     ackerbohne  ackerrettich  apfel  artischocken  austern  beeren  birne  \
# 0        False         False  False         False    False   False  False
# 1        False         False  False         False    False   False  False
# 2        False         False  False         False    False   False  False
# 3        False         False  False         False    False   False  False
# 4        False         False  False         False    False   False  False
# ..         ...           ...    ...           ...      ...     ...    ...
# 90       False         False  False         False    False   False  False
# 91       False         False  False         False    False   False  False
# 92       False         False  False         False    False   False  False
# 93       False         False  False         False    False   False  False
# 94       False         False  False         False    False   False  False
#
#     blumenkohl  bratenjus  bratfett  ...  weiße_bohnen  weißkohl  wirsing  \
# 0        False      False     False  ...         False     False    False
# 1        False      False     False  ...         False     False    False
# 2        False      False     False  ...         False     False    False
# 3        False      False     False  ...         False     False    False
# 4        False      False     False  ...         False     False    False
# ..         ...        ...       ...  ...           ...       ...      ...
# 90       False      False     False  ...         False     False    False
# 91       False      False     False  ...         False     False    False
# 92       False      False     False  ...         False     False    False
# 93       False      False     False  ...         False     False    False
# 94       False      False     False  ...         False     False    False
#
#     wurzeln   zimt  zitrone  zucker  zuckerschoten  zwieback  zwiebel
# 0     False  False    False   False          False     False    False
# 1     False  False    False   False          False      True    False
# 2      True  False    False    True          False     False    False
# 3     False  False    False   False          False      True    False
# 4     False  False    False   False          False      True    False
# ..      ...    ...      ...     ...            ...       ...      ...
# 90    False  False    False   False          False     False    False
# 91    False  False    False   False          False      True    False
# 92    False  False    False    True          False     False    False
# 93    False  False    False   False          False     False    False
# 94    False  False    False   False          False      True    False
#
# [95 rows x 99 columns]

# %% [markdown]
# Compute ingredient co-occurrences.

# %%
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.to_excel('fp_hdg.xlsx')
frequent_itemsets
# Out:
#      support                        itemsets  length
# 0   0.894737                        (butter)       1
# 1   0.315789                            (ei)       1
# 2   0.263158                         (essig)       1
# 3   0.305263                  (fleischbrühe)       1
# 4   0.368421                     (kartoffel)       1
# 5   0.400000                        (muskat)       1
# 6   0.315789                    (weizenmehl)       1
# 7   0.252632                      (zwieback)       1
# 8   0.294737                    (ei, butter)       2
# 9   0.252632                 (essig, butter)       2
# 10  0.305263          (fleischbrühe, butter)       2
# 11  0.284211             (kartoffel, butter)       2
# 12  0.400000                (muskat, butter)       2
# 13  0.305263            (butter, weizenmehl)       2
# 14  0.242105              (zwieback, butter)       2
# 15  0.231579          (fleischbrühe, muskat)       2
# 16  0.200000              (zwieback, muskat)       2
# 17  0.231579  (fleischbrühe, muskat, butter)       3
# 18  0.200000      (zwieback, muskat, butter)       3

# %% [markdown]
# Create association rules.

# %%
association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
# Out:
#                antecedents             consequents  antecedent support  \
# 0                     (ei)                (butter)            0.315789
# 1                 (butter)                    (ei)            0.894737
# 2                  (essig)                (butter)            0.263158
# 3                 (butter)                 (essig)            0.894737
# 4           (fleischbrühe)                (butter)            0.305263
# 5                 (butter)          (fleischbrühe)            0.894737
# 6              (kartoffel)                (butter)            0.368421
# 7                 (butter)             (kartoffel)            0.894737
# 8                 (muskat)                (butter)            0.400000
